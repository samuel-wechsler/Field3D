# %%
# %matplotlib widget
from main import *

# %%
def F(x, y, z):
    return vector(x, y, z)

field = Field(F)

# %%
import numpy as np
sin = np.sin
cos = np.cos

def x(u, v): return sin(u) * cos(v)
def y(u, v): return sin(u) * sin(u)
def z(u, v): return cos(v)

u = np.linspace(0, np.pi/2, 100)
v = np.linspace(0, 2 * np.pi, 100)

sphere = ParamSurface(x, y, z, u, v)
sphere.visualize()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b2ec1e066584> in <module>
#      11
#      12 sphere = ParamSurface(x, y, z, u, v)
# ---> 13 sphere.visualize()
#
# ~/Documents/Exsikkator/Ausgabe 3 FS24/main.py in visualize(self, ax)
#     221         ax = ax or self.ax or self.plot()
#     222
# --> 223         print(len(self.x))
#     224         print(len(self.y))
#     225         print(len(self.z))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot(self, xs, ys, zdir, *args, **kwargs)
#    1486         lines = super().plot(xs, ys, *args, **kwargs)
#    1487         for line in lines:
# -> 1488             art3d.line_2d_to_3d(line, zs=zs, zdir=zdir)
#    1489
#    1490         xs, ys, zs = art3d.juggle_axes(xs, ys, zs, zdir)
#
# ...
